# %%
from sklearn.metrics import mean_squared_error

actual = [100, 200, 300]

predicted = [110, 190, 280]

mse = mean_squared_error(
    actual,
    predicted
)

print("MSE:", mse)
# Out:
# MSE: 200.0
